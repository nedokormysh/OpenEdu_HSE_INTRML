# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/OpenEdu_HSE_INTRML/blob/week4/sem04_gd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Градиентный спуск

# %% [markdown]
# ### Необходимые для семинара библиотеки

# %%
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Напомним, что веса обновляются следующим образом:
#
# $$w^{(t+1)} = w^{(t)} - \alpha_t \nabla Q(w^{(t)}),$$
#
# а $j$-ая компонента градиента расписывается как
#
# $$\frac{\partial Q(w)}{w_j} = \frac{2}{l} \sum_{i=1}^{l}x_{ij}(\langle w, x_i \rangle - y_i).$$

# %% [markdown]
# ### Реализация градиентного спуска

# %%
from sklearn.base import BaseEstimator

class LinearRegression(BaseEstimator):
    def __init__(self, epsilon=1e-4, max_steps=1000, w0=None, alpha=1e-2):
        """
        epsilon: разница для нормы изменения весов 
        max_steps: максимальное количество шагов в градиентном спуске
        w0: np.array (d,) - начальные веса
        alpha: шаг обучения
        """
        self.epsilon = epsilon
        self.max_steps = max_steps
        self.w0 = w0
        self.alpha = alpha
        self.w = None
        self.w_history = []
    
    def fit(self, X, y):
        """
        X: np.array (l, d)
        y: np.array (l)
        ---
        output: self
        """
        l, d = X.shape

        # Если у нас не задано начальное приближение, давайте просто инициализировать веса нулями. 

        if self.w0 is None:
          self.w0 = np.zeros(d)
        # Это будет просто вектор размера d из нулей и давайте для w, которое будет нашими итоговыми весами, пока что присвоим w0.
        self.w = self.w0

        # нам нужно совершать итерации градиентного спуска, а делать мы это будем по количеству шагов, которое у нас задано max_steps.

        for step in range(self.max_steps):
          self.w_history.append(self.w)

          # рассчитываем веса

          w_new = self.w - self.alpha * self.calc_gradient(X, y)

          # новый вес для следующего шага и теперь нам нужно проверить еще одно условие: то, что наши веса не сильно различаются. Ес

          if (np.linalg.norm(w_new - self.w) < self.epsilon):
            break
          
          self.w = w_new
        
          # в качестве результата мы хотим возвращать просто сам класс

        return self
    
    def predict(self, X):
        """
        X: np.array (l, d)
        ---
        output: np.array (l)
        """
        
        if self.w is None:
            raise Exception('Not trained yet')
        
        l, d = X.shape

        y_pred = []

        for i in range(l):
          y_pred.append(np.dot(X[i], self.w))

        return np.array(y_pred)
    
    def calc_gradient(self, X, y):
        """
        X: np.array (l, d)
        y: np.array (l)
        ---
        output: np.array (d)
        """
        
        l, d = X.shape
        gradient = []
        
        for j in range(d):
          # нам нужно завести сумму, исходя из формулы. обозначим её первоначальное значение как dQ
          dQ = 0
          for i in range(l):
            dQ += (2/l) * X[i][j] * (np.dot(X[i], self.w) - y[i])
          gradient.append(dQ)

        return np.array(gradient)

# %% [markdown]
# ### Визуализация траектории градиентного спуска

# %%
def plot_gd(X, y, w_history):
    # compute level set
    A, B = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))

    levels = np.empty_like(A)
    for i in range(A.shape[0]):
        for j in range(A.shape[1]):
            w_tmp = np.array([A[i, j], B[i, j]])
            levels[i, j] = np.mean(np.power(np.dot(X, w_tmp) - y, 2))

    plt.figure(figsize=(13, 9))
    plt.title('GD trajectory')
    plt.xlabel(r'$w_1$')
    plt.ylabel(r'$w_2$')
    plt.xlim((-2.1, 2.1))
    plt.ylim((-2.1, 2.1))

    # visualize the level set
    CS = plt.contour(A, B, levels, levels=np.logspace(0, 2, num=10), cmap=plt.cm.rainbow_r)
    CB = plt.colorbar(CS, shrink=0.8, extend='both')

    # visualize trajectory
    w_list = np.array(lr.w_history)
    plt.scatter(w_true[0], w_true[1], c='r', marker='*')
    plt.scatter(w_list[:, 0], w_list[:, 1])
    plt.plot(w_list[:, 0], w_list[:, 1])
    plt.show()

# %%
n_features = 2
n_objects = 300
num_steps = 100

'''
Мы зафиксируем все наши случайные вычисления с помощью
его np.random.seed, и теперь мы случайным образом из нормального
распределения с параметрами 0 и 01 сгенерируем наши настоящие веса и
сгенерируем наше начальное приближение весов. Также у нас будут
обучающие данные, это будут случайные величины из равномерного распределения
от минус 5 до 5, и у нас будет целевая переменная, которая будет выражаться
просто как наша истинная зависимость с небольшим шумом.
'''
np.random.seed(1)
w_true = np.random.normal(0, 0.1, size=(n_features, ))
w_0 = np.random.uniform(-2, 2, (n_features))

X = np.random.uniform(-5, 5, (n_objects, n_features))
y = np.dot(X, w_true) + np.random.normal(0, 1, (n_objects))

# %%
lr = LinearRegression(w0=w_0)
lr.fit(X, y)

plot_gd(X, y, lr.w_history)

# %% [markdown]
# ### Влияние размера шага на сходимость
#
# Давайте сравним, как изменится поведение полного градиентного спуска в зависимости от размера шага.

# %% [markdown]
# $\alpha = 0.0001$

# %%
1e-2
# Out:
# 0.01

# %%
lr = LinearRegression(w0=w_0, alpha=0.0001)
lr.fit(X, y)
plot_gd(X, y, lr.w_history)

# %% [markdown]
# $\alpha = 0.01$ - наш стандартный шаг

# %%
lr = LinearRegression(w0=w_0, alpha=0.01)
lr.fit(X, y)
plot_gd(X, y, lr.w_history)

# %% [markdown]
# $\alpha = 0.1$
#
# Давайте теперь посмотрим на самый большой шаг градиентного спуска,
# и здесь мы видим совершенно иную картину: каждый раз, когда мы совершаем шаг
# градиентного спуска, мы движемся в сторону оптимума, но при
# этом мы делаем слишком большой шаг и перескакиваем через оптимум, и наши шаги
# очень большие, и мы каждый раз перелетаем через нужную нам точку.

# %%
lr = LinearRegression(w0=w_0, alpha=0.1)
lr.fit(X, y)
plot_gd(X, y, lr.w_history)

# %% [markdown]
# ### Масштабирование функции

# %% [markdown]
# Создадим новую матрицу объектов признаков и один из двух признаков увеличим в пять раз, то есть каждую компоненту мы умножаем на 5 и с теми же параметрами, с которыми наша модель сошлась хорошо, то есть это шаг 0.01, мы обучим эту линейную регрессию на нашей новой матрице объектов-признаков, при этом целевая переменная у нас остается такая же.

# %%
X_new = X.copy()
X_new[:,1] = X_new[:,1] * 5

lr = LinearRegression(w0=w_0, alpha=0.01)
lr.fit(X_new, y)
plot_gd(X_new, y, lr.w_history)

# %% [markdown]
# во-первых, мы видим то, что по одной из координат наша функция заметно вытянута, собственно, вытянута она в пять раз, и каждый раз, когда мы шагаем вдоль градиента, мы шагаем перпендикулярно линии уровня, о чем говорилось на лекции, и на шаг становится слишком большим, и мы перелетаем через оптимум, и мы не можем сойтись до хорошего значения. Мы сначала двигаемся постепенно в сторону оптимума, но дальше мы через него, так сказать, перелетаем, именно поэтому, когда мы обучаем наши линейные модели с помощью градиентного спуска, нам всегда необходимо масштабировать наши данные, например, стандартизировать их, как было рассказано в лекции.

# %% [markdown]
# ## Бонус
#
# ### Реализация полного градиентного спуска с матричными операциями

# %% [markdown]
# Градиент в матричной форме $$\nabla Q(w) = -2X^Ty + 2X^TXw = 2X^T(Xw - y).$$

# %%
class LinearRegressionVectorized(BaseEstimator):
    def __init__(self, epsilon=1e-4, max_steps=1000, w0=None, alpha=1e-2):
        """
        epsilon: разница для нормы изменения весов 
        max_steps: максимальное количество шагов в градиентном спуске
        w0: np.array (d,) - начальные веса
        alpha: шаг обучения
        """
        self.epsilon = epsilon
        self.max_steps = max_steps
        self.w0 = w0
        self.alpha = alpha
        self.w = None
        self.w_history = []
    
    def fit(self, X, y):
        """
        X: np.array (l, d)
        y: np.array (l)
        ---
        output: self
        """
        l, d = X.shape

        if self.w0 is None:
          self.w0 = np.zeros(d)

        self.w = self.w0

        for step in range(self.max_steps):
          self.w_history.append(self.w)

          w_new = self.w - self.alpha * self.calc_gradient(X, y)

          if (np.linalg.norm(w_new - self.w) < self.epsilon):
            break
          
          self.w = w_new
        
        return self
    '''
    У нас будет новый класс линейной регрессии, функцию fit, которая обучает, мы оставляем без изменений, нам нужно изменить
    только подсчет градиентов и функцию, которая дает нам предсказание. 
    '''

    def predict(self, X):
        """
        X: np.array (l, d)
        ---
        output: np.array (l)
        """
        
        if self.w is None:
            raise Exception('Not trained yet')
        # нам нужно матричный умножить x - матрицу объектов-признаков - на наш вектор весов w.
        return np.dot(X, self.w)

    
    def calc_gradient(self, X, y):
        """
        X: np.array (l, d)
        y: np.array (l)
        ---
        output: np.array (d)
        """
        l, d = X.shape

        return (2/l) * np.dot(X.T,(np.dot(X, self.w) - y))

# %% [markdown]
# ### Сравнение скорости работы обычной и матричной формы

# %%
n_features = 100
n_objects = 10000
num_steps = 2
'''
У нас для того, чтобы сравнение было более показательным, будет
100 признаков и 10 тысяч объектов, и для того,
чтобы наш пример отработал быстро, поставим количество шагов равным двум.
'''


np.random.seed(1)
w_true = np.random.normal(0, 0.1, size=(n_features, ))
w_0 = np.random.uniform(-2, 2, (n_features))

X = np.random.uniform(-5, 5, (n_objects, n_features))
y = np.dot(X, w_true) + np.random.normal(0, 1, (n_objects))

# %%
lr = LinearRegression(w0=w_0, alpha=0.01)
# %time lr.fit(X, y)
# Out:
# CPU times: user 2min 35s, sys: 401 ms, total: 2min 35s
# Wall time: 2min 36s
# LinearRegression(w0=array([ 1.22842078, -0.44855742,  1.45416742,  0.98848657,  0.22496094,
#        -1.4541791 , -1.76032924, -1.51462618, -1.82179249, -1.57002348,
#        -1.09716265,  0.85195592,  0.23886793, -1.94977608, -1.71210288,
#         1.86910532,  0.27240185, -1.18682706, -0.99069702,  0.97530342,
#        -1.21828208,  0.32543571,  1.88007996,  1.38731521, -1.04060896,
#        -0.02492114,  0.47982287,  1.3159236 , -1....
#         0.22661275,  1.6624254 ,  0.56626484, -0.43996914, -0.05603733,
#         0.41724193,  0.19819169,  1.70472571,  1.67493374, -0.42049755,
#         1.85305011, -1.30417733, -1.49468192, -1.45968337,  0.02264866,
#        -1.91390078,  1.79188084,  1.30846188, -1.93992408, -1.29521498,
#        -0.6717457 , -1.47601262,  1.23796277, -0.62105339,  1.76042993,
#         0.32805672,  1.51532794,  1.37893778,  1.62156927, -0.16047894,
# ...

# %% [markdown]
# Сразу видно то, что модель обучается достаточно долго за счет того, что у нас есть цикл и по количеству объектов и по количеству признаков.

# %%
lr_vectorized = LinearRegressionVectorized(w0=w_0, alpha=0.01)
# %time lr_vectorized.fit(X, y)
# Out:
# CPU times: user 102 ms, sys: 15 ms, total: 117 ms
# Wall time: 69 ms
# LinearRegressionVectorized(alpha=0.01, epsilon=0.0001, max_steps=1000,
#                            w0=array([ 1.22842078, -0.44855742,  1.45416742,  0.98848657,  0.22496094,
#        -1.4541791 , -1.76032924, -1.51462618, -1.82179249, -1.57002348,
#        -1.09716265,  0.85195592,  0.23886793, -1.94977608, -1.71210288,
#         1.86910532,  0.27240185, -1.18682706, -0.99069702,  0.97530342,
#        -1.21828208,  0.32543571,  1.88007996,  1.387315...
#         0.22661275,  1.6624254 ,  0.56626484, -0.43996914, -0.05603733,
#         0.41724193,  0.19819169,  1.70472571,  1.67493374, -0.42049755,
#         1.85305011, -1.30417733, -1.49468192, -1.45968337,  0.02264866,
#        -1.91390078,  1.79188084,  1.30846188, -1.93992408, -1.29521498,
#        -0.6717457 , -1.47601262,  1.23796277, -0.62105339,  1.76042993,
#         0.32805672,  1.51532794,  1.37893778,  1.62156927, -0.16047894,
# ...

# %% [markdown]
# Видно то, что общее время заняло максимум 117 миллисекунд.
# Ну, по сравнению с обычной линейной моделью, которая у нас не отработала даже
# примерно за полторы минуты. В этом видео мы реализовали обучение линейной
# регрессии с помощью градиентного спуска в матричной форме и сравнили скорость
# работы с обычной реализацией градиентного спуска.
